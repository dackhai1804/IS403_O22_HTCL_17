# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, GRU
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error
df = pd.read_csv('FPT.csv', index_col='time', parse_dates=True)
df=df.drop(columns=['open', 'high', 'low', 'volume'])
df = df.reset_index(drop=True)
df.head()
# Out:
#           close
# 0  19318.330078
# 1  19491.587891
# 2  19448.273438
# 3  19318.330078
# 4  19383.300781

# %%
# 2. Đọc file csv và gắn index với Price
df1=df.reset_index()['close']

# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# 4. Chia train test
train_size = int(0.7 * len(df1))
test_size = len(df1) - train_size

train_data = df1[:train_size]
test_data = df1[train_size:]

# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
time_step = 30
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# 7. Reshape input to be [samples, time steps, features] which is required for GRU
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
# 8. Define GRU Model
model = Sequential()
model.add(GRU(64, input_shape=(time_step, 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 4s 60ms/step - loss: 0.0334 - val_loss: 0.0305
# Epoch 2/100
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0095 - val_loss: 0.0258
# Epoch 3/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0033 - val_loss: 0.0042
# Epoch 4/100
# 14/14 [==============================] - 0s 24ms/step - loss: 4.4289e-04 - val_loss: 3.8683e-04
# Epoch 5/100
# 14/14 [==============================] - 0s 23ms/step - loss: 2.6992e-04 - val_loss: 4.3085e-04
# Epoch 6/100
# 14/14 [==============================] - 0s 25ms/step - loss: 1.5354e-04 - val_loss: 2.8429e-04
# Epoch 7/100
# 14/14 [==============================] - 0s 24ms/step - loss: 1.4671e-04 - val_loss: 2.8940e-04
# Epoch 8/100
# 14/14 [==============================] - 0s 23ms/step - loss: 1.3295e-04 - val_loss: 2.6535e-04
# Epoch 9/100
# 14/14 [==============================] - 0s 25ms/step - loss: 1.2863e-04 - val_loss: 2.7175e-04
# Epoch 10/100
# 14/14 [==============================] - 0s 24ms/step - loss: 1.2756e-04 - val_loss: 2.5903e-04
# Epoch 11/100
# 14/14 [==============================] - 0s 24ms/step - loss: 1.2544e-04 - val_loss: 2.5682e-04
# Epoch 12/100
# 14/14 [==============================] - 0s 26ms/step - loss: 1.2544e-04 - val_loss: 2.4899e-04
# Epoch 13/100
# 14/14 [==============================] - 0s 23ms/step - loss: 1.2186e-04 - val_loss: 2.4628e-04
# Epoch 14/100
# 14/14 [==============================] - 0s 24ms/step - loss: 1.2271e-04 - val_loss: 2.4228e-04
# Epoch 15/100
# 14/14 [==============================] - 0s 26ms/step - loss: 1.1848e-04 - val_loss: 2.4295e-04
# Epoch 16/100
# 14/14 [==============================] - 0s 24ms/step - loss: 1.1717e-04 - val_loss: 2.4965e-04
# Epoch 17/100
# 14/14 [==============================] - 0s 24ms/step - loss: 1.1552e-04 - val_loss: 2.3978e-04
# Epoch 18/100
# 14/14 [==============================] - 0s 25ms/step - loss: 1.1407e-04 - val_loss: 2.5550e-04
# Epoch 19/100
# 14/14 [==============================] - 0s 24ms/step - loss: 1.1256e-04 - val_loss: 2.5200e-04
# Epoch 20/100
# 14/14 [==============================] - 0s 23ms/step - loss: 1.1423e-04 - val_loss: 2.7890e-04
# Epoch 21/100
# 14/14 [==============================] - 0s 25ms/step - loss: 1.1215e-04 - val_loss: 2.8334e-04
# Epoch 22/100
# 14/14 [==============================] - 0s 25ms/step - loss: 1.1226e-04 - val_loss: 3.2301e-04
# Epoch 23/100
# 14/14 [==============================] - 0s 23ms/step - loss: 1.1249e-04 - val_loss: 2.6537e-04
# Epoch 24/100
# 14/14 [==============================] - 0s 25ms/step - loss: 1.0663e-04 - val_loss: 2.7716e-04
# Epoch 25/100
# 14/14 [==============================] - 0s 24ms/step - loss: 1.0611e-04 - val_loss: 2.6159e-04
# Epoch 26/100
# 14/14 [==============================] - 0s 26ms/step - loss: 1.0579e-04 - val_loss: 2.5443e-04
# Epoch 27/100
# 14/14 [==============================] - 1s 38ms/step - loss: 1.0364e-04 - val_loss: 2.6148e-04
# Epoch 28/100
# 14/14 [==============================] - 0s 36ms/step - loss: 1.0288e-04 - val_loss: 2.7501e-04
# Epoch 29/100
# 14/14 [==============================] - 0s 35ms/step - loss: 1.0142e-04 - val_loss: 2.3861e-04
# Epoch 30/100
# 14/14 [==============================] - 1s 38ms/step - loss: 1.
100
# 14/14 [==============================] - 0s 27ms/step - loss: 7.7834e-05 - val_loss: 4.1086e-04
# Epoch 87/100
# 14/14 [==============================] - 0s 26ms/step - loss: 7.5517e-05 - val_loss: 3.5113e-04
# Epoch 88/100
# 14/14 [==============================] - 0s 24ms/step - loss: 8.1245e-05 - val_loss: 3.1905e-04
# Epoch 89/100
# 14/14 [==============================] - 0s 25ms/step - loss: 7.5924e-05 - val_loss: 3.8604e-04
# Epoch 90/100
# 14/14 [==============================] - 0s 25ms/step - loss: 7.3869e-05 - val_loss: 3.6599e-04
# Epoch 91/100
# 14/14 [==============================] - 0s 26ms/step - loss: 7.4292e-05 - val_loss: 4.6177e-04
# Epoch 92/100
# 14/14 [==============================] - 0s 25ms/step - loss: 7.6928e-05 - val_loss: 2.9167e-04
# Epoch 93/100
# 14/14 [==============================] - 0s 25ms/step - loss: 7.5050e-05 - val_loss: 4.6411e-04
# Epoch 94/100
# 14/14 [==============================] - 0s 27ms/step - loss: 7.3978e-05 - val_loss: 3.3089e-04
# Epoch 95/100
# 14/14 [==============================] - 0s 25ms/step - loss: 7.3122e-05 - val_loss: 3.0459e-04
# Epoch 96/100
# 14/14 [==============================] - 0s 27ms/step - loss: 7.4276e-05 - val_loss: 2.9862e-04
# Epoch 97/100
# 14/14 [==============================] - 0s 27ms/step - loss: 7.4900e-05 - val_loss: 4.2959e-04
# Epoch 98/100
# 14/14 [==============================] - 0s 27ms/step - loss: 7.5572e-05 - val_loss: 3.5347e-04
# Epoch 99/100
# 14/14 [==============================] - 1s 38ms/step - loss: 7.3464e-05 - val_loss: 3.3371e-04
# Epoch 100/100
# 14/14 [==============================] - 0s 36ms/step - loss: 7.2448e-05 - val_loss: 3.4002e-04

# %%
# Dự báo dữ liệu test
y_pred = model.predict(X_test)

# Chuẩn hóa dữ liệu y_pred
y_pred_new = scaler.inverse_transform(y_pred.reshape(1, -1))
y_test_new = scaler.inverse_transform(np.array([y_test], dtype=np.float32))
# Out:
# 12/12 [==============================] - 0s 6ms/step

# %%
from sklearn.metrics import mean_squared_log_error

# Tính toán RMSE, MAPE và MLSE trên tập test
test_score_rmse = np.sqrt(mean_squared_error(y_test_new, y_pred_new))
test_score_mape = mean_absolute_percentage_error(y_test_new, y_pred_new) * 100
test_score_msle = mean_squared_log_error(y_test_new, y_pred_new)

print('RMSE trên tập test là:', test_score_rmse)
print('MAPE trên tập test là:', test_score_mape, '%')
print('MSLE trên tập test là:', test_score_msle)
# Out:
# RMSE trên tập test là: 2079.4136
# MAPE trên tập test là: 1.530985627323389 %
# MSLE trên tập test là: 0.0004583628

# %%
# Dự báo 30 ngày tiếp theo
x_input = test_data[-time_step:].reshape(1, -1)
temp_input = list(x_input[0])
lst_output = []

for i in range(30):
    if len(temp_input) > time_step:
        x_input = np.array(temp_input[1:]).reshape(1, -1)
        x_input = x_input.reshape((1, time_step, 1))
        y_hat = model.predict(x_input, verbose=0)
        temp_input.extend(y_hat[0].tolist())
        temp_input = temp_input[1:]
        lst_output.extend(y_hat.tolist())
    else:
        x_input = x_input.reshape((1, time_step, 1))
        y_hat = model.predict(x_input, verbose=0)
        temp_input.extend(y_hat[0].tolist())
        lst_output.extend(y_hat.tolist())

# %%
# Visualize the predictions
plt.figure(figsize=(12, 6))
plt.plot(scaler.inverse_transform(df1), label='Train')
test_data_index = pd.RangeIndex(start=train_size, stop=train_size + test_size, step=1)
plt.plot(test_data_index, scaler.inverse_transform(test_data), label='Actual Test')
test_pred_index = pd.RangeIndex(start=train_size + time_step, stop=train_size + test_size - 1, step=1)
plt.plot(test_pred_index, scaler.inverse_transform(y_pred.reshape(-1, 1)), label='Predicted Test')
predict_data_index = pd.RangeIndex(start=len(df1), stop=len(df1) + 30, step=1)
plt.plot(predict_data_index, scaler.inverse_transform(lst_output), label='Next 30 days')
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('Stock Price Prediction')
plt.legend()
plt.show()

# %% [markdown]
# # (Split 8/2)

# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, GRU
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error
df = pd.read_csv('FPT.csv', index_col='time', parse_dates=True)
df=df.drop(columns=['open', 'high', 'low', 'volume'])
df = df.reset_index(drop=True)
df.head()
# Out:
#           close
# 0  19318.330078
# 1  19491.587891
# 2  19448.273438
# 3  19318.330078
# 4  19383.300781

# %%
# 2. Đọc file csv và gắn index với Price
df1=df.reset_index()['close']

# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# 4. Chia train test
train_size = int(0.8 * len(df1))
test_size = len(df1) - train_size

train_data = df1[:train_size]
test_data = df1[train_size:]

# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
time_step = 30
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# 7. Reshape input to be [samples, time steps, features] which is required for GRU
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
# 8. Define GRU Model
model = Sequential()
model.add(GRU(64, input_shape=(time_step, 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 17/17 [==============================] - 3s 52ms/step - loss: 0.0232 - val_loss: 0.0114
# Epoch 2/100
# 17/17 [==============================] - 0s 22ms/step - loss: 0.
_pred_new = scaler.inverse_transform(y_pred.reshape(1, -1))
y_test_new = scaler.inverse_transform(np.array([y_test], dtype=np.float32))
# Out:
# 8/8 [==============================] - 1s 9ms/step

# %%
from sklearn.metrics import mean_squared_log_error

# Tính toán RMSE, MAPE và MLSE trên tập test
test_score_rmse = np.sqrt(mean_squared_error(y_test_new, y_pred_new))
test_score_mape = mean_absolute_percentage_error(y_test_new, y_pred_new) * 100
test_score_msle = mean_squared_log_error(y_test_new, y_pred_new)

print('RMSE trên tập test là:', test_score_rmse)
print('MAPE trên tập test là:', test_score_mape, '%')
print('MSLE trên tập test là:', test_score_msle)
# Out:
# RMSE trên tập test là: 2243.091
# MAPE trên tập test là: 1.7141133546829224 %
# MSLE trên tập test là: 0.00051863893

# %%
# Dự báo 30 ngày tiếp theo
x_input = test_data[-time_step:].reshape(1, -1)
temp_input = list(x_input[0])
lst_output = []

for i in range(30):
    if len(temp_input) > time_step:
        x_input = np.array(temp_input[1:]).reshape(1, -1)
        x_input = x_input.reshape((1, time_step, 1))
        y_hat = model.predict(x_input, verbose=0)
        temp_input.extend(y_hat[0].tolist())
        temp_input = temp_input[1:]
        lst_output.extend(y_hat.tolist())
    else:
        x_input = x_input.reshape((1, time_step, 1))
        y_hat = model.predict(x_input, verbose=0)
        temp_input.extend(y_hat[0].tolist())
        lst_output.extend(y_hat.tolist())

# %%
# Visualize the predictions
plt.figure(figsize=(12, 6))
plt.plot(scaler.inverse_transform(df1), label='Train')
test_data_index = pd.RangeIndex(start=train_size, stop=train_size + test_size, step=1)
plt.plot(test_data_index, scaler.inverse_transform(test_data), label='Actual Test')
test_pred_index = pd.RangeIndex(start=train_size + time_step, stop=train_size + test_size - 1, step=1)
plt.plot(test_pred_index, scaler.inverse_transform(y_pred.reshape(-1, 1)), label='Predicted Test')
predict_data_index = pd.RangeIndex(start=len(df1), stop=len(df1) + 30, step=1)
plt.plot(predict_data_index, scaler.inverse_transform(lst_output), label='Next 30 days')
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('Stock Price Prediction')
plt.legend()
plt.show()

# %% [markdown]
# # (Split 9/1)

# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, GRU
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error
df = pd.read_csv('FPT.csv', index_col='time', parse_dates=True)
df=df.drop(columns=['open', 'high', 'low', 'volume'])
df = df.reset_index(drop=True)
df.head()
# Out:
#           close
# 0  19318.330078
# 1  19491.587891
# 2  19448.273438
# 3  19318.330078
# 4  19383.300781

# %%
# 2. Đọc file csv và gắn index với Price
df1=df.reset_index()['close']

# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# 4. Chia train test
train_size = int(0.9 * len(df1))
test_size = len(df1) - train_size

train_data = df1[:train_size]
test_data = df1[train_size:]

# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
time_step = 30
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# 7. Reshape input to be [samples, time steps, features] which is required for GRU
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
# 8. Define GRU Model
model = Sequential()
model.add(GRU(64, input_shape=(time_step, 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 19/19 [==============================] - 3s 47ms/step - loss: 0.0329 - val_loss: 0.0183
# Epoch 2/100
# 19/19 [==============================] - 0s 21ms/step - loss: 0.0063 - val_loss: 0.0322
# Epoch 3/100
# 19/19 [==============================] - 0s 23ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 4/100
# 19/19 [==============================] - 0s 20ms/step - loss: 2.0741e-04 - val_loss: 8.4515e-04
# Epoch 5/100
# 19/19 [==============================] - 0s 20ms/step - loss: 1.6497e-04 - val_loss: 5.6522e-04
# Epoch 6/100
# 19/19 [==============================] - 0s 22ms/step - loss: 1.4697e-04 - val_loss: 6.1528e-04
# Epoch 7/100
# 19/19 [==============================] - 0s 20ms/step - loss: 1.4425e-04 - val_loss: 5.2348e-04
# Epoch 8/100
# 19/19 [==============================] - 0s 23ms/step - loss: 1.4012e-04 - val_loss: 5.2341e-04
# Epoch 9/100
# 19/19 [==============================] - 0s 20ms/step - loss: 1.3659e-04 - val_loss: 5.0017e-04
# Epoch 10/100
# 19/19 [==============================] - 0s 20ms/step - loss: 1.3528e-04 - val_loss: 4.7759e-04
# Epoch 11/100
# 19/19 [==============================] - 0s 25ms/step - loss: 1.3348e-04 - val_loss: 4.8039e-04
# Epoch 12/100
# 19/19 [==============================] - 1s 31ms/step - loss: 1.3234e-04 - val_loss: 4.8599e-04
# Epoch 13/100
# 19/19 [==============================] - 1s 32ms/step - loss: 1.2784e-04 - val_loss: 4.8117e-04
# Epoch 14/100
# 19/19 [==============================] - 1s 32ms/step - loss: 1.2754e-04 - val_loss: 4.4307e-04
# Epoch 15/100
# 19/19 [==============================] - 1s 31ms/step - loss: 1.2651e-04 - val_loss: 4.3557e-04
# Epoch 16/100
# 19/19 [==============================] - 1s 37ms/step - loss: 1.3021e-04 - val_loss: 4.3093e-04
# Epoch 17/100
# 19/19 [==============================] - 1s 34ms/step - loss: 1.2397e-04 - val_loss: 4.9759e-04
# Epoch 18/100
# 19/19 [==============================] - 0s 25ms/step - loss: 1.1890e-04 - val_loss: 6.1772e-04
# Epoch 19/100
# 19/19 [==============================] - 0s 23ms/step - loss: 1
100
# 19/19 [==============================] - 0s 22ms/step - loss: 8.2987e-05 - val_loss: 6.4466e-04
# Epoch 82/100
# 19/19 [==============================] - 0s 23ms/step - loss: 7.9880e-05 - val_loss: 4.4536e-04
# Epoch 83/100
# 19/19 [==============================] - 0s 22ms/step - loss: 8.1188e-05 - val_loss: 8.1504e-04
# Epoch 84/100
# 19/19 [==============================] - 0s 22ms/step - loss: 8.1086e-05 - val_loss: 4.0971e-04
# Epoch 85/100
# 19/19 [==============================] - 0s 21ms/step - loss: 7.5817e-05 - val_loss: 4.0348e-04
# Epoch 86/100
# 19/19 [==============================] - 0s 22ms/step - loss: 7.5736e-05 - val_loss: 4.8832e-04
# Epoch 87/100
# 19/19 [==============================] - 0s 22ms/step - loss: 7.6458e-05 - val_loss: 5.8169e-04
# Epoch 88/100
# 19/19 [==============================] - 0s 21ms/step - loss: 7.7105e-05 - val_loss: 4.7616e-04
# Epoch 89/100
# 19/19 [==============================] - 0s 22ms/step - loss: 7.5619e-05 - val_loss: 5.2379e-04
# Epoch 90/100
# 19/19 [==============================] - 0s 21ms/step - loss: 7.6052e-05 - val_loss: 5.1912e-04
# Epoch 91/100
# 19/19 [==============================] - 0s 22ms/step - loss: 7.6872e-05 - val_loss: 4.3681e-04
# Epoch 92/100
# 19/19 [==============================] - 0s 23ms/step - loss: 7.9213e-05 - val_loss: 4.3994e-04
# Epoch 93/100
# 19/19 [==============================] - 0s 22ms/step - loss: 7.4603e-05 - val_loss: 3.1293e-04
# Epoch 94/100
# 19/19 [==============================] - 0s 22ms/step - loss: 7.7334e-05 - val_loss: 4.8764e-04
# Epoch 95/100
# 19/19 [==============================] - 0s 21ms/step - loss: 7.6510e-05 - val_loss: 5.1638e-04
# Epoch 96/100
# 19/19 [==============================] - 0s 22ms/step - loss: 7.4240e-05 - val_loss: 4.0402e-04
# Epoch 97/100
# 19/19 [==============================] - 0s 22ms/step - loss: 7.4696e-05 - val_loss: 4.0007e-04
# Epoch 98/100
# 19/19 [==============================] - 0s 22ms/step - loss: 7.6677e-05 - val_loss: 3.4799e-04
# Epoch 99/100
# 19/19 [==============================] - 0s 22ms/step - loss: 7.4939e-05 - val_loss: 3.2976e-04
# Epoch 100/100
# 19/19 [==============================] - 0s 21ms/step - loss: 7.4904e-05 - val_loss: 3.3129e-04

# %%
# Dự báo dữ liệu test
y_pred = model.predict(X_test)

# Chuẩn hóa dữ liệu y_pred
y_pred_new = scaler.inverse_transform(y_pred.reshape(1, -1))
y_test_new = scaler.inverse_transform(np.array([y_test], dtype=np.float32))
# Out:
# 4/4 [==============================] - 0s 6ms/step

# %%
from sklearn.metrics import mean_squared_log_error

# Tính toán RMSE, MAPE và MLSE trên tập test
test_score_rmse = np.sqrt(mean_squared_error(y_test_new, y_pred_new))
test_score_mape = mean_absolute_percentage_error(y_test_new, y_pred_new) * 100
test_score_msle = mean_squared_log_error(y_test_new, y_pred_new)

print('RMSE trên tập test là:', test_score_rmse)
print('MAPE trên tập test là:', test_score_mape, '%')
print('MSLE trên tập test là:', test_score_msle)
# Out:
# RMSE trên tập test là: 2052.542
# MAPE trên tập test là: 1.392162125557661 %
# MSLE trên tập test là: 0.00037716998

# %%
# Dự báo 30 ngày tiếp theo
x_input = test_data[-time_step:].reshape(1, -1)
temp_input = list(x_input[0])
lst_output = []

for i in range(30):
    if len(temp_input) > time_step:
        x_input = np.array(temp_input[1:]).reshape(1, -1)
        x_input = x_input.reshape((1, time_step, 1))
        y_hat = model.predict(x_input, verbose=0)
        temp_input.extend(y_hat[0].tolist())
        temp_input = temp_input[1:]
        lst_output.extend(y_hat.tolist())
    else:
        x_input = x_input.reshape((1, time_step, 1))
        y_hat = model.predict(x_input, verbose=0)
        temp_input.extend(y_hat[0].tolist())
        lst_output.extend(y_hat.tolist())

# %%
# Visualize the predictions
plt.figure(figsize=(12, 6))
plt.plot(scaler.inverse_transform(df1), label='Train')
test_data_index = pd.RangeIndex(start=train_size, stop=train_size + test_size, step=1)
plt.plot(test_data_index, scaler.inverse_transform(test_data), label='Actual Test')
test_pred_index = pd.RangeIndex(start=train_size + time_step, stop=train_size + test_size - 1, step=1)
plt.plot(test_pred_index, scaler.inverse_transform(y_pred.reshape(-1, 1)), label='Predicted Test')
predict_data_index = pd.RangeIndex(start=len(df1), stop=len(df1) + 30, step=1)
plt.plot(predict_data_index, scaler.inverse_transform(lst_output), label='Next 30 days')
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('Stock Price Prediction')
plt.legend()
plt.show()
